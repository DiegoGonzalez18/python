# %%
from mnist import MNIST
mdata= MNIST('MNIST_data')

# %%
datos, labels =mdata.load_training()

# %%
# %matplotlib inline
from  matplotlib import pyplot as plt

# %%
import numpy as np

# %%
plt.gray()

# %% [markdown]
# plt.green()

# %%
 for i in range(81):
    plt.subplot(9,9,i+1)
    d_image=datos[i]
    d_image=np.array(d_image)
    pixels=d_image.reshape((28,28))
    plt.imshow(pixels,cmap='gray')
    plt.axis('off')
plt.show()

# %%
plt.black()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-03bfb0a0e987> in <module>
# ----> 1 plt.black()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'black'

# %%
 for i in range(81):
    plt.subplot(9,9,i+1)
    d_image=datos[i]
    d_image=np.array(d_image)
    pixels=d_image.reshape((28,28))
    plt.imshow(pixels,cmap='gray')
    plt.axis('off')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data,train_labels,test_labels=train_test_split(datos,labels,test_size=0.3, random_state=42)
