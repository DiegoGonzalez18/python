# %%
'hola'+'hola'
# Out:
# 'holahola'

# %%
'hola '+'platzi'
# Out:
# 'hola platzi'

# %%
'Diego '*3
# Out:
# 'Diego Diego Diego '

# %%
pi=3.141516
radio=3
area=pi* (radio**2)
print(area)
# Out:
# 28.273644

# %%
radio=5
area=pi* (radio**2)

# %%
print (area)
# Out:
# 78.53790000000001

# %%
# -*- coding: utf-8 -*-
name = str( input('¿Cual es tu nombre?'))
print('hola, ' + name + '!')
# Out:
# ¿Cual es tu nombre?Diego
# hola, Diego!
