# %%
def run():
    print('Calculadora de divisas')
    print('Convierte pesos mexicanos a pesos colombianos.')
    print('')
    
    ammount= float(input('Ingresa los pesos mexicanos que deseas convertir '))
    result= foreign_exchange_calculator(ammount)
    print('${} pesos mexicanos son ${} pesos colombianoa'.format(ammount,result))
    print('')
    
def foreign_exchange_calculator(ammount):
    mex_to_col_rate=145.97
    return mex_to_col_rate*ammount


if __name__== '__main__':
    run()
# Out:
# Calculadora de divisas
# Convierte pesos mexicanos a pesos colombianos.
#
# Ingresa los pesos mexicanos que deseas convertir 200
# $200.0 pesos mexicanos son $29194.0 pesos colombianoa
