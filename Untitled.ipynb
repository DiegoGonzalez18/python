# %%
import turtle

# %%
window = turtle.Screen()
diego = turtle.Turtle()
diego.forward(50)
diego.left(90)
diego.forward(50)
diego.left(90)
diego.forward(50)
diego.left(90)
diego.forward(50)
diego.left(90)

turtle.mainloop()

# %%
4+4
# Out:
# 8

# %% [markdown]
# 2**2

# %%
2**2
# Out:
# 4

# %%
2***2
# Out:
#   File "<ipython-input-7-d9e3a121487a>", line 1
#     2***2
#        ^
# SyntaxError: invalid syntax

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
2**1000
# Out:
# 

# %%
4<5
# Out:
# True

# %%
1==5
# Out:
# False

# %%
5>=5
# Out:
# True

# %%
2*4+4
# Out:
# 12

# %%
2/4*1
# Out:
# 0.5

# %%
print('hola')
# Out:
# hola

# %%
type(2.6)
# Out:
# float
