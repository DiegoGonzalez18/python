# %%
#lista=[] # lista=list()
#lista.append('pedro')
#lista.append('yo')
#lista.append('aca')
#lista[1]
def promedio(lista):
   b=len(lista)
   suma=0
   i=0
   
   for i in range(b):
    suma+=lista[i]
   print((suma/b))


if __name__=='__main__':
        lista=[21,24,24,22,20,23,24]
        promedio(lista)
# Out:
# 22.571428571428573

# %%
lista=[1]
lista2=[2,3,4]
lista3=lista+lista2
lista3
# Out:
# [1, 2, 3, 4]

# %%
lista*5
# Out:
# [1, 1, 1, 1, 1]
