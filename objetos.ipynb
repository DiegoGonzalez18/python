# %%
class Lamp:
    _LAMPS = ['''
          .
     .    |    ,
      \   '   /
       ` ,-. '
    --- (   ) ---
         \ /
        _|=|_
       |_____|
    ''',
    '''
         ,-.
        (   )
         \ /
        _|=|_
       |_____|
    ''']

    def __init__(self, is_turned_on):
        self._is_turned_on = is_turned_on

    def turn_on(self):
        self._is_turned_on = True
        self._display_image()

    def turn_off(self):
        self._is_turned_on = False
        self._display_image()

    def _display_image(self):
        if self._is_turned_on:
            print(self._LAMPS[0])
        else:
            print(self._LAMPS[1])
    def run():
        lamp = Lamp(is_turned_on=False)

        while True:
            
            command = str(input('''
            ¿Qué deseas hacer?

            [p]render
            [a]pagar
            [s]alir
            '''))

            if command == 'p':
                lamp.turn_on()
            elif command == 'a':
                
                lamp.turn_off()
            else:
                break
            
    if __name__== '__main__':
        run()
# Out:
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#             a
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-3bc3c21afbeb> in <module>
# ----> 1 class Lamp:
#       2     _LAMPS = ['''
#       3           .
#       4      .    |    ,
#       5       \   '   /
#
# <ipython-input-25-3bc3c21afbeb> in Lamp()
#      56
#      57     if __name__== '__main__':
# ---> 58         run()
#      59
#      60
#
# <ipython-input-25-3bc3c21afbeb> in run()
#      51             elif command == 'a':
#      52
# ---> 53                 lamp.turn_off()
#      54             else:
#      55                 break
#
# AttributeError: 'Lamp' object has no attribute 'turn_off'

# %%
class Lamp:
    _LAMPS = ['''
          .
     .    |    ,
      \   '   /
       ` ,-. '
    --- (   ) ---
         \ /
        _|=|_
       |_____|
    ''',
    '''
         ,-.
        (   )
         \ /
        _|=|_
       |_____|
    ''']

    def __init__(self, is_turned_on):
        self._is_turned_on = is_turned_on

    def turn_on(self):
        self._is_turned_on = True
        self._display_image()

    def turn_off(self):
        self._is_turned_on = False
        self._display_image()

    def _display_image(self):
        if self._is_turned_on:
            print(self._LAMPS[0])
        else:
            print(self._LAMPS[1])

# %%
def run():
    lamp = Lamp(is_turned_on=False)

    while True:
        command = str(input('''
            ¿Qué deseas hacer?

            [p]render
            [a]pagar
            [s]alir
        '''))

        if command == 'p':
            lamp.turn_on()
        elif command == 'a':
            lamp.turn_off()
        else:
            break


if __name__ == '__main__':
    run()
# Out:
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#         p
#
#           .
#      .    |    ,
#       \   '   /
#        ` ,-. '
#     --- (   ) ---
#          \ /
#         _|=|_
#        |_____|
#
#
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#         a
#
#          ,-.
#         (   )
#          \ /
#         _|=|_
#        |_____|
#
#
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#         s

# %%
class Lamp:
    _LAMPS = ['''
          .
     .    |    ,
      \   '   /
       ` ,-. '
    --- (   ) ---
         \ /
        _|=|_
       |_____|
    ''',
    '''
         ,-.
        (   )
         \ /
        _|=|_
       |_____|
    ''']

    def __init__(self, is_turned_on):
        self._is_turned_on = is_turned_on

    def turn_on(self):
        self._is_turned_on = True
        self._display_image()

    def turn_off(self):
        self._is_turned_on = False
        self._display_image()

    def _display_image(self):
        if self._is_turned_on:
            print(self._LAMPS[0])
        else:
            print(self._LAMPS[1])
    def run():
        lamp = Lamp(is_turned_on=False)

        while True:
            
            command = str(input('''
            ¿Qué deseas hacer?

            [p]render
            [a]pagar
            [s]alir
            '''))

            if command == 'p':
                lamp.turn_on()
            elif command == 'a':
                
                lamp.turn_off()
            else:
                break
            
    if __name__== '__main__':
        run()
# Out:
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#             p
#
#           .
#      .    |    ,
#       \   '   /
#        ` ,-. '
#     --- (   ) ---
#          \ /
#         _|=|_
#        |_____|
#
#
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#             a
#
#          ,-.
#         (   )
#          \ /
#         _|=|_
#        |_____|
#
#
#             ¿Qué deseas hacer?
#
#             [p]render
#             [a]pagar
#             [s]alir
#             s
